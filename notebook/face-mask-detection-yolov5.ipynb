# %% [markdown]
# # Setup the Environment
# We are going to use YOLOv5 model for training.
# so lets clone and install the YOLO from github repo

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -qr requirements.txt

# %%
# Import required libraries
import pandas as pd
import numpy as np
import os
import glob
from datetime import datetime
import xml.etree.ElementTree as ET 
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
input_data = '/home/dung/Desktop/dataset/face-mask-detection'
output_data = 'home/dung/Desktop/face-mask-dection/notebook'

# %% [markdown]
# # Read and Handle Annotations
# Read the data from .xml files
# <br>
# Extract filename and dimensions of the bouding boxes
# <br>
# and import that data into a pandas DataFrame

# %%
annotations_path = "/home/dung/Desktop/dataset/face-mask-detection/annotations"
images_path = "/home/dung/Desktop/dataset/face-mask-detection/images"

# %%
dataset = {
            "file":[],
            "name":[],    
            "width":[],
            "height":[],
            "xmin":[],
            "ymin":[],   
            "xmax":[],
            "ymax":[],
           }

for anno in glob.glob(annotations_path+"/*.xml"):
    tree = ET.parse(anno)
    
    for elem in tree.iter():
        if 'size' in elem.tag:
            for attr in list(elem):
                if 'width' in attr.tag: 
                    width = int(round(float(attr.text)))
                if 'height' in attr.tag:
                    height = int(round(float(attr.text)))    

        if 'object' in elem.tag:
            for attr in list(elem):
                
                if 'name' in attr.tag:
                    name = attr.text                 
                    dataset['name']+=[name]
                    dataset['width']+=[width]
                    dataset['height']+=[height] 
                    dataset['file']+=[anno.split('/')[-1][0:-4]] 
                            
                if 'bndbox' in attr.tag:
                    for dim in list(attr):
                        if 'xmin' in dim.tag:
                            xmin = int(round(float(dim.text)))
                            dataset['xmin']+=[xmin]
                        if 'ymin' in dim.tag:
                            ymin = int(round(float(dim.text)))
                            dataset['ymin']+=[ymin]                                
                        if 'xmax' in dim.tag:
                            xmax = int(round(float(dim.text)))
                            dataset['xmax']+=[xmax]                                
                        if 'ymax' in dim.tag:
                            ymax = int(round(float(dim.text)))
                            dataset['ymax']+=[ymax]

# %%
df=pd.DataFrame(dataset)
df.head()
# Out:
#               file                   name  width  height  xmin  ymin  xmax  \
# 0  maksssksksss647  mask_weared_incorrect    400     265    21    40    66
# 1  maksssksksss647           without_mask    400     265    82    21   108
# 2  maksssksksss647              with_mask    400     265   134    44   152
# 3  maksssksksss647              with_mask    400     265   150    75   182
# 4  maksssksksss647              with_mask    400     265    62   159   145
#
#    ymax
# 0    87
# 1    43
# 2    67
# 3   109
# 4   240

# %%
name_dict = {
    'with_mask': 0,
    'mask_weared_incorrect': 1,
    'without_mask': 2 
}

df['class'] = df['name'].map(name_dict)

# %%
np.sort(df.name.unique())
# Out:
# array(['mask_weared_incorrect', 'with_mask', 'without_mask'], dtype=object)

# %% [markdown]
# # Train Test Split
# Split the dataset into training testing and validation set
# <br>
# separate the data in different folder inside the Yolo directory
# <br>
# and Normalize data

# %%
fileNames = [*os.listdir("/home/dung/Desktop/dataset/face-mask-detection/images")]
print('There are {} images in the dataset'.format(len(fileNames)))
# Out:
# There are 853 images in the dataset

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(fileNames, test_size=0.1, random_state=22)
test, val = train_test_split(test, test_size=0.7, random_state=22)
print("Length of Train =",len(train))
print("="*30)
print("Length of Valid =",len(val))
print("="*30)
print("Length of test =", len(test))
# Out:
# Length of Train = 767
# ==============================
# Length of Valid = 61
# ==============================
# Length of test = 25

# %%
# create separate train test and validation dir inside yolo/data/
os.chdir('/home/dung/Desktop/face-mask-detection/notebook')
# os.mkdir('./yolov5/data/train')
# os.mkdir('./yolov5/data/val')
# os.mkdir('./yolov5/data/test')
# os.mkdir('./yolov5/data/train/images')
# os.mkdir('./yolov5/data/train/labels')
# os.mkdir('./yolov5/data/test/images')
# os.mkdir('./yolov5/data/test/labels')
# os.mkdir('./yolov5/data/val/images')
# os.mkdir('./yolov5/data/val/labels')

# %%
from PIL import Image

def copyImages(imageList, folder_Name):
    for image in imageList:
        img = Image.open(input_data + "/images/" + image)
        img1 = img.resize((640, 480))
        _ = img1.save("/home/dung/Desktop/face-mask-detection/notebook/yolov5/data/train/images" + image)

copyImages(train, "train")
copyImages(val, "val")
copyImages(test, "test")

# %%
df.head()
# Out:
#               file                   name  width  height  xmin  ymin  xmax  \
# 0  maksssksksss647  mask_weared_incorrect    400     265    21    40    66
# 1  maksssksksss647           without_mask    400     265    82    21   108
# 2  maksssksksss647              with_mask    400     265   134    44   152
# 3  maksssksksss647              with_mask    400     265   150    75   182
# 4  maksssksksss647              with_mask    400     265    62   159   145
#
#    ymax  class
# 0    87      1
# 1    43      2
# 2    67      0
# 3   109      0
# 4   240      0

# %%
df['xmax'] = (640/df['width'])*df['xmax']
df['ymax'] = (480/df['height'])*df['ymax']
df['xmin'] = (640/df['width'])*df['xmin']
df['ymin'] = (480/df['height'])*df['ymin']

# %%
df[['xmax', 'ymax', 'xmin', 'ymin']] = df[['xmax', 'ymax', 'xmin', 'ymin']].astype('int64')

# %%
df['x_center'] = (df['xmax']+df['xmin'])/(2*640)
df['y_center'] = (df['ymax']+df['ymin'])/(2*480)
df['box_height'] = (df['xmax']-df['xmin'])/(640)
df['box_width'] = (df['ymax']-df['ymin'])/(480)

# %%
df.head()
# Out:
#               file                   name  width  height  xmin  ymin  xmax  \
# 0  maksssksksss647  mask_weared_incorrect    400     265    33    72   105
# 1  maksssksksss647           without_mask    400     265   131    38   172
# 2  maksssksksss647              with_mask    400     265   214    79   243
# 3  maksssksksss647              with_mask    400     265   240   135   291
# 4  maksssksksss647              with_mask    400     265    99   288   232
#
#    ymax  class  x_center  y_center  box_height  box_width
# 0   157      1  0.107813  0.238542    0.112500   0.177083
# 1    77      2  0.236719  0.119792    0.064062   0.081250
# 2   121      0  0.357031  0.208333    0.045312   0.087500
# 3   197      0  0.414844  0.345833    0.079687   0.129167
# 4   434      0  0.258594  0.752083    0.207813   0.304167

# %%
df = df.astype('string')

# %%
def create_labels(image_list, data_name):
    fileNames = [x.split(".")[0] for x in image_list]

    for name in fileNames:
        data = df[df.file==name]
        box_list = []
        
        for index in range(len(data)):
            row = data.iloc[index]
            box_list.append(row['class'] + " "+row["x_center"] + " " + row["y_center"]\
                         + " " + row["box_height"] + " " + row["box_width"])
            
        text = "\n".join(box_list)
        with open("/home/dung/Desktop/face-mask-detection/notebook/yolov5/data/train/labels" + name + ".txt", "w") as file:
            file.write(text)


create_labels(train, "train")
create_labels(val, "val")
create_labels(test, "test")

# %% [markdown]
# # Configure the Model

# %%
# go to YOLO directory
# %cd yolov5
# Out:
# /home/dung/Desktop/face-mask-detection/notebook/yolov5

# %%
# to display images
from IPython.display import Image, clear_output
import torch
from yolov5 import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v6.1-105-gd257c75 torch 1.12.0+cu102 CPU
# Setup complete ✅ (8 CPUs, 15.4 GB RAM, 47.3/60.3 GB disk)

# %%
# configure .yaml file to guide the model for training
yaml_text = """train: data/train/images
val: data/train/images

nc: 3
names: ['with_mask', 'mask_weared_incorrect', 'without_mask']"""

with open("data/data.yaml", 'w') as file:
    file.write(yaml_text)

# %cat data/data.yaml
# Out:
# train: data/train/images
# val: data/train/images
#
# nc: 3
# names: ['with_mask', 'mask_weared_incorrect', 'without_mask']

# %%
#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# %%writetemplate models/custom_yolov5s.yaml
#
# # parameters
# nc: 3  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
#
# # anchors
# anchors:
#     - [10,13, 16,30, 33,23]  # P3/8
#     - [30,61, 62,45, 59,119]  # P4/16
#     - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 9, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, BottleneckCSP, [1024, False]],  # 9
#   ]
#
# # YOLOv5 head
# head:
#     [[-1, 1, Conv, [512, 1, 1]],
#     [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#     [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#     [-1, 3, BottleneckCSP, [512, False]],  # 13
#
#     [-1, 1, Conv, [256, 1, 1]],
#     [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#     [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#     [-1, 3, BottleneckCSP, [256, False]],  # 17 (P3/8-small)
#
#     [-1, 1, Conv, [256, 3, 2]],
#     [[-1, 14], 1, Concat, [1]],  # cat head P4
#     [-1, 3, BottleneckCSP, [512, False]],  # 20 (P4/16-medium)
#
#     [-1, 1, Conv, [512, 3, 2]],
#     [[-1, 10], 1, Concat, [1]],  # cat head P5
#     [-1, 3, BottleneckCSP, [1024, False]],  # 23 (P5/32-large)
#
#     [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#     ]

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
# we are going to using pre-trained weights from yolov5.pt model

start = datetime.now()
# !python3 train.py --img 640 --batch 32 --epochs 50 --data data/data.yaml --cfg models/custom_yolov5s.yaml --weights yolov5s.pt --name yolov5s_results  --cache
end = datetime.now()
# Out:
# Downloading https://ultralytics.com/assets/Arial.ttf to /home/dung/.config/Ultralytics/Arial.ttf...
# train: weights=yolov5s.pt, cfg=models/custom_yolov5s.yaml, data=data/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 2576, done.
# remote: Counting objects: 100% (716/716), done.
# remote: Compressing objects: 100% (5/5), done.
# Command 'git fetch && git config --get remote.origin.url' timed out after 5 seconds
# YOLOv5 🚀 v6.1-105-gd257c75 torch 1.12.0+cu102 CPU228.00 KiB/s
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# 2022-07-30 17:53:07.442148: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-07-30 17:53:07.507811: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/dung/.local/lib/python3.10/site-packages/cv2/../../lib64:/home/dung/.local/lib/python3.10/site-packages/cv2/../../lib64:
# 2022-07-30 17:53:07.507846: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# remote: Total 2576 (delta 713), reused 711 (delta 711), pack-reused 1860
# Receiving objects: 100% (2576/2576), 1.19 MiB | 294.00 KiB/s, done.
# Resolving deltas: 100% (1775/1775), completed with 131 local objects.
# From https://github.com/ultralytics/yolov5
#    d257c75..52d3a9a  master                 -> origin/master
#  * [new branch]      add/weights_dir        -> origin/add/weights_dir
#    0f0ffe2..2594685  classifier             -> origin/classifier
#  * [new branch]      coco-segments          -> origin/coco-segments
#  * [new branch]      fix/rgb_albumentations -> origin/fix/rgb_albumentations
#  * [new branch]      pip                    -> origin/pip
#  * [new branch]      test/FReLU_v2          -> origin/test/FReLU_v2
#    85a2b97..c58f17a  test/conv_reduction    -> origin/test/conv_reduction
#  * [new branch]      test/convtranspose     -> origin/test/convtranspose
#  * [new branch]      test/dw5               -> origin/test/dw5
#  * [new branch]      test/frelu             -> origin/test/frelu
#  * [new branch]      test/frelu2            -> origin/test/frelu2
#  * [new branch]      test/poly              -> origin/test/poly
#  * [new branch]      test/seeds             -> origin/test/seeds
#  * [new branch]      test/smoothing         -> origin/test/smoothing
#  * [new branch]      ultralytics/HUB        -> origin/ultralytics/HUB
#  * [new branch]      update/textlogger      -> origin/update/textlogger
#  * [new branch]      v7.0                   -> origin/v7.0
#  * [new branch]      v7.0.1                 -> origin/v7.0.1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     19904  models.common.BottleneckCSP             [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  3    161152  models.common.BottleneckCSP             [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    641792  models.common.BottleneckCSP             [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    378624  models.common.BottleneckCSP             [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     95104  models.common.BottleneckCSP             [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    313088  models.common.BottleneckCSP             [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  24      [17, 20, 23]  1     21576  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# custom_YOLOv5s summary: 283 layers, 7260488 parameters, 7260488 gradients, 16.9 GFLOPs
#
# Transferred 223/369 items from yolov5s.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 59 weight (no decay), 70 weight, 62 bias
# train: Scanning '/home/dung/Desktop/face-mask-detection/notebook/yolov5/data/tra
# train: New cache created: /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/train/labels.cache
# train: Caching images (0.1GB ram):  13%|█▎        | 97/767 [00:00<00:01, 467.10ilibpng warning: iCCP: Not recognizing known sRGB profile that has been edited
# train: Caching images (0.7GB ram): 100%|██████████| 767/767 [00:01<00:00, 493.51
# val: Scanning '/home/dung/Desktop/face-mask-detection/notebook/yolov5/data/train
# val: Caching images (0.3GB ram):  47%|████▋     | 361/767 [00:01<00:01, 377.46itlibpng warning: iCCP: Not recognizing known sRGB profile that has been edited
# val: Caching images (0.7GB ram): 100%|██████████| 767/767 [00:02<00:00, 291.34it
# Plotting labels to runs/train/yolov5s_results2/labels.jpg...
#
# AutoAnchor: 5.66 anchors/target, 0.999 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/yolov5s_results2
# Starting training for 50 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   0%|          | 0/24 [00:00<?, ?it/s]

# %%
print("Runtime =",end-start)
# Out:
# Runtime = 0:00:27.110029

# %%
# lets visualize the training results
img = plt.imread('runs/train/yolov5s_results/train_batch0.jpg')
plt.figure(figsize=(20,15))
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# # Test the Model
# lets test the model over test images we had separated before training

# %%
# !python3 detect.py --source data/test/images/ --weight runs/train/yolov5s_results/weights/best.pt --name expTestImage --conf 0.4
# Out:
# detect: weights=['runs/train/yolov5s_results/weights/best.pt'], source=data/test/images/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=expTestImage, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-105-gd257c75 torch 1.12.0+cu102 CPU
#
# Fusing layers...
# custom_YOLOv5s summary: 232 layers, 7251912 parameters, 0 gradients
# image 1/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss151.png: 480x640 9 with_masks, Done. (0.121s)
# image 2/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss164.png: 480x640 6 with_masks, 3 without_masks, Done. (0.091s)
# image 3/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss173.png: 480x640 2 with_masks, Done. (0.084s)
# image 4/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss193.png: 480x640 2 with_masks, Done. (0.120s)
# image 5/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss236.png: 480x640 1 without_mask, Done. (0.116s)
# image 6/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss24.png: 480x640 Done. (0.117s)
# image 7/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss323.png: 480x640 1 with_mask, Done. (0.133s)
# image 8/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss381.png: 480x640 4 with_masks, Done. (0.118s)
# image 9/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss433.png: 480x640 1 with_mask, Done. (0.116s)
# image 10/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss466.png: 480x640 4 with_masks, 1 without_mask, Done. (0.118s)
# image 11/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss497.png: 480x640 1 with_mask, Done. (0.119s)
# image 12/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss607.png: 480x640 2 with_masks, Done. (0.117s)
# image 13/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss611.png: 480x640 5 with_masks, Done. (0.117s)
# image 14/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss630.png: 480x640 1 with_mask, Done. (0.117s)
# image 15/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss640.png: 480x640 10 with_masks, Done. (0.115s)
# image 16/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss65.png: 480x640 2 with_masks, 1 without_mask, Done. (0.116s)
# image 17/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss658.png: 480x640 1 with_mask, Done. (0.100s)
# image 18/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss747.png: 480x640 1 with_mask, Done. (0.084s)
# image 19/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss750.png: 480x640 6 without_masks, Done. (0.085s)
# image 20/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss755.png: 480x640 6 with_masks, Done. (0.081s)
# image 21/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss770.png: 480x640 5 with_masks, 2 without_masks, Done. (0.086s)
# image 22/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss772.png: 480x640 2 without_masks, Done. (0.084s)
# image 23/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss796.png: 480x640 13 with_masks, Done. (0.084s)
# image 24/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss797.png: 480x640 6 with_masks, Done. (0.088s)
# image 25/25 /home/dung/Desktop/face-mask-detection/notebook/yolov5/data/test/images/maksssksksss848.png: 480x640 3 with_masks, Done. (0.084s)
# Speed: 0.6ms pre-process, 104.4ms inference, 0.8ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/expTestImage2

# %% [markdown]
# results are saved inside run/detect/expTestImage dir <br>
# let's check the results to see how our model performed

# %%
color_dict = {
    'with_mask': (0, 255, 0),
    'mask_weared_incorrect':  (0, 0, 255),
    'without_mask': (255, 0, 0) 
}

# %%
def show_image(img_id):
    df_image = df[df.file==img_id]
    df_image[['xmin', 'ymin', 'xmax', 'ymax']] = df_image[['xmin', 'ymin', 'xmax', 'ymax']].astype('int64')
    path = 'data/test/images/'+img_id# +'.png'
    img = plt.imread(path)

    imge = img.copy()

    for index in range(len(df_image)):
        row = df_image.iloc[index]
        cv2.rectangle(imge, 
                      (row['xmin'], row['ymin']),
                      (row['xmax'], row['ymax']),
                      color=color_dict[row['name']],
                      thickness=2)

    img_pred = plt.imread('runs/detect/expTestImage/'+img_id)
    # ===================================
    plt.figure(figsize=(14,17))

    plt.subplot(1,2,1)
    plt.imshow(imge)
    plt.axis('off')
    plt.title('Image with Truth Box')

    plt.subplot(1,2,2)
    plt.imshow(img_pred)
    plt.axis('off')
    plt.title('Image with Predicted Box')

# %%
import os, random
show_image(random.choice(os.listdir("data/test/images/"))) 
show_image(random.choice(os.listdir("data/test/images/"))) 
plt.show()
